# %% [markdown]
# # 시각화
#
# - 자료 분석의 기본은 통계와 그래프
#   - 통계는 수치를 통해서 자료를 이해
#   - 시각화는 자료에 대한 직관적인 이해
# - 시각화 하는 방법은 정해져 있습니다
#   - 자료의 형태에 따라서, 자료의 개수에 따라서
# - 빅데이터에서는 무수히 많은 변수를 다룹니다

# %% [markdown]
# ## 시각화 라이브러리
#
# ### matplotlib
#
# - 가장 기본적인 시각화 라이브러리
# - 파이썬에서 제공하는 대부분의 다른 시각화 라이브러리들도 matplotlib 기반으로 구현
#
# ### seaborn
#
# - 사용하기 쉬움
# - 자료의 시각화를 하는 경우에 많이 사용
#
# ### plotly
#
# - 예쁘고, 사용하기 편함, 특히 3차원 그래프도 편하게 그릴 수 있음
# - 회전, 확대, 클릭 등 인터렉티브한 사용 가능
# - 굉장히 무겁고 느림
#
# ## 한글화
#
# - 기본적으로 matplotlib 은 한글을 지원하지 않습니다
#   - 한글을 표현하기 위해선 폰트를 바꿔줘야 합니다

# %%
import numpy as np
import pandas as pd
import matplotlib as plt
from matplotlib import font_manager, rc
import matplotlib.pyplot as pl
import seaborn as sns

# %%
font_path = 'C:\\WINDOWS\\Fonts\\batang.ttc'
font = font_manager.FontProperties(fname=font_path).get_name()
rc('font', family=font)

# %% [markdown]
# ## 그래프를 그리는 기준
#
# - 통계분석에서도 동일한 기준으로 분석을 합니다
#
# 1. 자료의 형태(변수의 종류)
#    - 범주형과 연속형 자료로 구분해볼 수 있습니다
#    - 질적변수(범주형) vs 양적변수(연속형)
#      - 질적변수 : 변수의 값이 비 수치적, 특정 카테고리에 포함되는 경우
#        - 명목형 : 특정 범주에 포함되지만, 순위를 갖지 않는 경우(성별, 혈액형)
#        - 순위형 : 특정 범주에 포함되면서, 순위를 갖는 경우(성적, 등급)
#      - 양적변수 : 변수의 값이 수치적, 연속적인 경우(키, 나이)
#        - 이산형 : 셀 수 있는 경우(정수인 경우)
#        - 연속형 : 셀 수 없는 경우(실수인 경우)
# 2. 자료의 차원(변수의 개수)
#    - 차원이 높으면, 시각화를 해볼 수 없습니다
#      - 최대 2차원의 화면에서 3차원 까지만 나타낼 수 있습니다
#    - 1차원 : 일변수(일변량), 변수 하나에 대한 시각화 및 통계
#      - 변수의 분포 등을 확인
#    - 2차원 : 이변수(이변량)
#      - 변수와 변수의 관계를 확인하고 싶은 경우
#      - 연속형 변수와 연속형 변수
#      - 연속형 변수와 이산형 변수
#      - 이산형 변수와 이산형 변수
#
# ### 1차원 시각화
#
# - 변수 1개인 경우
#   - 범주형인 경우 : countplot(빈도 확인)
#   - 연속형인 경우 : histplot, displot
#
# ### 범주형
#
# - 샘플 자료에서는 비수치적인 자료는 없습니다
#   - 수치적인 사료들(이산형) 중에서 범주형에 해당하는 변수를 확인
#   - 흡연상태, 구강검진 수검여부, 성별

# %%
df = pd.read_csv('C:/Users/BAUM/Desktop/multicampus/TIL/data/health_2016.csv')

# %%
df['흡연상태'].unique()
# Out:
# array([3., 1., 2.])

# %%
df['구강검진 수검여부'].unique()
# Out:
# array([1, 0], dtype=int64)

# %%
df['성별코드'].unique()
# Out:
# array([1, 2], dtype=int64)

# %%
sns.countplot(data=df, x='흡연상태')
# Out:
# <AxesSubplot:xlabel='흡연상태', ylabel='count'>

# %%
sns.countplot(data=df, x='구강검진 수검여부')
# Out:
# <AxesSubplot:xlabel='구강검진 수검여부', ylabel='count'>

# %%
sns.countplot(data=df, x='성별코드')
# Out:
# <AxesSubplot:xlabel='성별코드', ylabel='count'>

# %%
sns.countplot(data=df, x='연령대코드(5세단위)')
# Out:
# <AxesSubplot:xlabel='연령대코드(5세단위)', ylabel='count'>

# %%
sns.countplot(data=df, x='시도코드')
# Out:
# <AxesSubplot:xlabel='시도코드', ylabel='count'>

# %%
sns.countplot(data=df, x='신장(5Cm단위)')
# Out:
# <AxesSubplot:xlabel='신장(5Cm단위)', ylabel='count'>

# %% [markdown]
# ## 연속형

# %%
df.columns
# Out:
# Index(['기준년도', '가입자일련번호', '성별코드', '연령대코드(5세단위)', '시도코드', '신장(5Cm단위)',
#        '체중(5Kg단위)', '허리둘레', '시력(좌)', '시력(우)', '청력(좌)', '청력(우)', '수축기혈압',
#        '이완기혈압', '식전혈당(공복혈당)', '총콜레스테롤', '트리글리세라이드', 'HDL콜레스테롤', 'LDL콜레스테롤',
#        '혈색소', '요단백', '혈청크레아티닌', '(혈청지오티)AST', '(혈청지오티)ALT', '감마지티피', '흡연상태',
#        '음주여부', '구강검진 수검여부', '치아우식증유무', '결손치유무', '치아마모증유무', '제3대구치(사랑니)이상',
#        '치석', '데이터공개일자'],
#       dtype='object')

# %%
sns.histplot(data=df, x='총콜레스테롤')
# Out:
# <AxesSubplot:xlabel='총콜레스테롤', ylabel='Count'>

# %%
sns.histplot(data=df, x='트리글리세라이드')
# Out:
# <AxesSubplot:xlabel='트리글리세라이드', ylabel='Count'>

# %%
df[df['트리글리세라이드'] > 700]
tmp = df.drop(index=[51, 195, 473, 942])
sns.histplot(data=tmp, x='트리글리세라이드')
# Out:
# <AxesSubplot:xlabel='트리글리세라이드', ylabel='Count'>

# %%
pl.hist(df['트리글리세라이드'], bins=1000)
pl.xlim(0, 250)
pl.show()

# %%
sns.displot(data=df, x='총콜레스테롤')

# %%
sns.displot(data=df, x='총콜레스테롤', kde=True)  # kde = 확률밀도함수

# %% [markdown]
# ## 2차원 시각화
#
# - 두 자료간의 관계를 확인하고 싶은 경우
#   - 타겟변수와 입력변수들간의 관계 (인과성)
#   - 입력변수와 입력변수들간의 관계 (상관성)
#     - 입력변수들은 서로 독립적임을 가정
# - 두 변수 모두 연속형
#   - scatterplot, lineplot, jointplot, rugplot...
# - 연속형 변수와 범주형 변수
#   - barplot, boxplot
# - 두 변수 모두 범주형
#   - countplot
#
# ### 두 변수 모두 연속형

# %%
sns.scatterplot(data=df, x='총콜레스테롤', y='트리글리세라이드')
# Out:
# <AxesSubplot:xlabel='총콜레스테롤', ylabel='트리글리세라이드'>

# %%
df[['총콜레스테롤', '트리글리세라이드']].corr()
# Out:
#             총콜레스테롤  트리글리세라이드
# 총콜레스테롤    1.000000  0.300108
# 트리글리세라이드  0.300108  1.000000

# %%
sns.lmplot(data=df, x='총콜레스테롤', y='트리글리세라이드')

# %%
sns.displot(data=df, x='총콜레스테롤', kde=True, color='violet')

# %%
sns.regplot(data=df, x='총콜레스테롤', y='트리글리세라이드', line_kws={'color': 'violet'})
# Out:
# <AxesSubplot:xlabel='총콜레스테롤', ylabel='트리글리세라이드'>

# %%
sns.jointplot(data=tmp, x='LDL콜레스테롤', y='총콜레스테롤')

# %%
sns.regplot(data=tmp, x='LDL콜레스테롤', y='총콜레스테롤', line_kws={'color': 'violet'})
# Out:
# <AxesSubplot:xlabel='LDL콜레스테롤', ylabel='총콜레스테롤'>

# %% [markdown]
# - 파생변수
#   - 주어진 자료에서 타겟변수를 가장 잘 설명할 수 있는 새로운 변수를 만들어 내는 것
#   - 데이터 마이닝 이라고 합니다
#   - 분석에서 제일 중요한 부분
#
# - 통계가 잘 적용되고 있는 분야
#   - 날씨, 항공, 군사, 마켓팅
#   - 이런 분야들에서는 변수에 대한 연구가 10 ~ 20년 동안 계속 이뤄지고 있음

# %%
sns.barplot(data=df, x='흡연상태', y='총콜레스테롤')
# Out:
# <AxesSubplot:xlabel='흡연상태', ylabel='총콜레스테롤'>

# %%
sns.barplot(data=df, x='흡연상태', y='총콜레스테롤', ci=False)
# Out:
# <AxesSubplot:xlabel='흡연상태', ylabel='총콜레스테롤'>

# %%
df.columns
# Out:
# Index(['기준년도', '가입자일련번호', '성별코드', '연령대코드(5세단위)', '시도코드', '신장(5Cm단위)',
#        '체중(5Kg단위)', '허리둘레', '시력(좌)', '시력(우)', '청력(좌)', '청력(우)', '수축기혈압',
#        '이완기혈압', '식전혈당(공복혈당)', '총콜레스테롤', '트리글리세라이드', 'HDL콜레스테롤', 'LDL콜레스테롤',
#        '혈색소', '요단백', '혈청크레아티닌', '(혈청지오티)AST', '(혈청지오티)ALT', '감마지티피', '흡연상태',
#        '음주여부', '구강검진 수검여부', '치아우식증유무', '결손치유무', '치아마모증유무', '제3대구치(사랑니)이상',
#        '치석', '데이터공개일자'],
#       dtype='object')

# %%
sns.countplot(data=df, x='성별코드', hue='흡연상태')
# Out:
# <AxesSubplot:xlabel='성별코드', ylabel='count'>

# %%
sns.boxplot(data=df, x='흡연상태', y='LDL콜레스테롤')
# Out:
# <AxesSubplot:xlabel='흡연상태', ylabel='LDL콜레스테롤'>

# %% [markdown]
# - boxplot
#    - 탐색적 자료분석 (EDA)에서 주로 많이 사용
#    - 4분위수를 이용한 시각화
#      - 이상치를 확인하는 용도로 사용
#      - 자료를 4개의 구간으로 나눈 값
#      - 1분위수 : 자료의 25%에 해당하는 값
#      - 2분위수 : 자료의 50%에 해당하는 값 (중앙값과 동일)
#      - 3부위수 : 자료의 75%에 해당하는 값
#     - IQR
#       - IQR = 3Q - Q1
#       - 최대 제한선 = 3Q + (iqr * 1.5)
#       - 최소 제한선 = 1Q = (IQR * 1.5)

# %% [markdown]
# ## 변수가 3개 이상인 경우
# - 최대 4개까지 표현을 해볼 수 있습니다
# - 변수의 종류에 따라 달라집니다

# %%
sns.barplot(data=df, x='흡연상태', y='총콜레스테롤', hue='성별코드')
# Out:
# <AxesSubplot:xlabel='흡연상태', ylabel='총콜레스테롤'>

# %%
pl.figure(figsize=(10,5))
sns.scatterplot(data=df, x = 'LDL콜레스테롤', y='총콜레스테롤', hue='성별코드', size='흡연상태')
# Out:
# <AxesSubplot:xlabel='LDL콜레스테롤', ylabel='총콜레스테롤'>

# %%
pl.figure(figsize=(12, 5))
pl.subplot(2, 2, 1)
sns.countplot(data=df, x='흡연상태')

pl.subplot(2, 2, 2)
sns.barplot(data=df, x='흡연상태', y='LDL콜레스테롤')

pl.subplot(2, 2, 3)
sns.regplot(data=df, x='총콜레스테롤', y='LDL콜레스테롤', line_kws=({'color':'violet'}))

pl.subplot(2, 2, 4)
sns.boxplot(data=df, x='흡연상태', y='LDL콜레스테롤')
# Out:
# <AxesSubplot:xlabel='흡연상태', ylabel='LDL콜레스테롤'>

# %%
fig, ax = pl.subplots(2, 2, figsize=(15, 9))
sns.countplot(data=df, x='흡연상태', ax=ax[0,0])
sns.barplot(data=df, x='흡연상태', y='LDL콜레스테롤', ax=ax[0, 1])
sns.regplot(data=df, x='총콜레스테롤', y='LDL콜레스테롤',
            line_kws=({'color': 'violet'}), ax=ax[1, 0])
sns.boxplot(data=df, x='흡연상태', y='LDL콜레스테롤', ax=ax[1, 1])
# Out:
# <AxesSubplot:xlabel='흡연상태', ylabel='LDL콜레스테롤'>
