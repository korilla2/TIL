# %%
import matplotlib.pyplot as plt

# %%
plt.plot([1, 2, 3, 4])
plt.ylabel('Y-label')
plt.show()

# %%
plt.plot([1, 2, 3, 4])
plt.ylabel('한글깨짐확인')
plt.show()
# Out:
# C:\Users\BAUM\AppData\Local\Programs\Python\Python39\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 54620 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\BAUM\AppData\Local\Programs\Python\Python39\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 44544 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\BAUM\AppData\Local\Programs\Python\Python39\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 44648 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\BAUM\AppData\Local\Programs\Python\Python39\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 51664 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\BAUM\AppData\Local\Programs\Python\Python39\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 54869 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\BAUM\AppData\Local\Programs\Python\Python39\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 51064 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\BAUM\AppData\Local\Programs\Python\Python39\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 54620 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\BAUM\AppData\Local\Programs\Python\Python39\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 44544 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\BAUM\AppData\Local\Programs\Python\Python39\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 44648 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\BAUM\AppData\Local\Programs\Python\Python39\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 51664 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\BAUM\AppData\Local\Programs\Python\Python39\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 54869 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\BAUM\AppData\Local\Programs\Python\Python39\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 51064 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
import os


# Mac OS의 경우와 그 외 OS의 경우로 나누어 설정

if os.name == 'posix':

    plt.rc("font", family="AppleGothic")

else:

    plt.rc("font", family="Malgun Gothic")

# %%
plt.plot([1, 2, 3, 4])
plt.ylabel('한글깨짐확인')
plt.show()

# %%
plt.plot([1, 2, 3, 4], [10, 50, 30, 100])

# %%
plt.plot([1, 2, 3, 4])

# %%
plt.xlabel('x축 레이블', labelpad=30, loc='right')
plt.ylabel('y축 레이블', loc='top')
# Out:
# Text(0, 1, 'y축 레이블')

# %%
plt.plot([1, 2, 3, 4], [10, 50, 30, 100], label='코딩유치원')

plt.legend()

# %%
plt.title('그래프 제목')
# Out:
# Text(0.5, 1.0, '그래프 제목')

# %%
plt.plot([1, 2, 3, 4], [10, 50, 30, 100])

# [X최소값, X최대값, Y최소값, Y최대값]
plt.axis([1, 3, 10, 60])
# Out:
# (1.0, 3.0, 10.0, 60.0)

# %%
plt.plot([1, 2, 3, 4], [2, 3, 5, 10], color='r', marker='o', linestyle='--')

# %%
plt.plot([1, 2, 3, 4], [2, 3, 5, 10], color='tomato')

# %%
# 포맷 문자열 방식 (‘ - ‘ (Solid), ‘ - - ‘ (Dashed), ‘ : ‘ (Dotted), ‘ -. ‘ (Dash-dot))
plt.plot([3, 3, 3], '-', color='C0', label='Solid')

# linestyle 지정 방식
plt.plot([2, 2, 2], linestyle='dashed', color='C0', label="'dashed'")

# linestyle에 튜플 방식 (커스터마이즈 가능)  --> 4개 이상의 선이 동시에 필요할 때 사용
plt.plot([1, 1, 1], linestyle=(0, (3, 5, 1, 5)),
         color='C0', label='(0, (3, 5, 1, 5))')

plt.legend(loc=(0.6, 0.7), ncol=1, fontsize=7)

# %%
plt.plot([4, 5, 6], marker="H")
plt.plot([3, 4, 5], marker="d")
plt.plot([2, 3, 4], marker="x")
plt.plot([1, 2, 3], marker=11)
plt.plot([0, 1, 2], marker='$Z$')

# %%
plt.plot([1, 2, 3, 4])

# %%
import numpy as np
plt.plot([1, 2, 3, 4])

# x축 눈금 설정
plt.xticks([0, 1, 2, 3])

# Numpy의 어레이로도 설정 가능


# y축 눈금 설정
plt.yticks(np.arange(1, 5, 1))
# Out:
# ([<matplotlib.axis.YTick at 0x2b931e7c5b0>,
#   <matplotlib.axis.YTick at 0x2b931e77e50>,
#   <matplotlib.axis.YTick at 0x2b931e77160>,
#   <matplotlib.axis.YTick at 0x2b931eb0040>],
#  [Text(0, 0, ''), Text(0, 0, ''), Text(0, 0, ''), Text(0, 0, '')])

# %%
import numpy as np

x = np.arange(0, 100, 0.2)

plt.plot(x, x**2)

plt.title('코딩유치원 월간 방문자 수')
plt.xticks([0, 20, 40, 60, 80, 100], labels=[
           'FEB', 'MAR', 'APR', 'MAY', 'JUN', 'JUL'])
plt.yticks([0, 400, 1600, 3600, 6400, 10000],
           ('0회', '400회', '1600회', '3600회', '6400회', '10000회'))
# Out:
# ([<matplotlib.axis.YTick at 0x2b930dc18b0>,
#   <matplotlib.axis.YTick at 0x2b931ec7cd0>,
#   <matplotlib.axis.YTick at 0x2b931ec1ee0>,
#   <matplotlib.axis.YTick at 0x2b931f025b0>,
#   <matplotlib.axis.YTick at 0x2b931f02ca0>,
#   <matplotlib.axis.YTick at 0x2b931f08430>],
#  [Text(0, 0, '0회'),
#   Text(0, 400, '400회'),
#   Text(0, 1600, '1600회'),
#   Text(0, 3600, '3600회'),
#   Text(0, 6400, '6400회'),
#   Text(0, 10000, '10000회')])

# %%
plt.tick_params(axis='x', direction='in', length=5, pad=6,
                labelsize=10, labelcolor='blue', top=True)

# %%
plt.grid(True)

# %%
# 가로선이 그려짐

plt.grid(True, axis='y')

# 세로선이 그려짐

plt.grid(True, axis='x')

# %%
plt.grid(True, color='red', alpha=0.5, linestyle='--')

# %%
# data 생성
data = np.arange(1, 11)

# 그래프 그리기
plt.plot(data)

# 그래프를 보여주는 코드 (주피터 노트북에서는 안해줘도 그래프 출력됨)
plt.show()

# %%
data1 = np.arange(1, 11)
plt.plot(data1)

data2 = np.arange(11, 21)
plt.plot(data2)

plt.show()

# %%
data1 = np.arange(1, 11)
plt.plot(data1)

# 캔버스  추가
plt.figure()

data2 = np.arange(11, 21)
plt.plot(data2)

plt.show()

# %%
# 2행 2열로 canvas를 나누어 1번(1행 1열) 칸에 subplot 그리기
data1 = np.arange(1, 11)
plt.subplot(2, 2, 1)
plt.plot(data1)

# 2행 2열로 canvas를 나누어 3번(2행 1열) 칸에 subplot 그리기
data2 = np.arange(11, 21)
plt.subplot(2, 2, 3)
plt.plot(data2 * 3)

# 2행 2열로 canvas를 나누어 4번(2행 2열) 칸에 subplot 그리기
data3 = np.arange(21, 31)
plt.subplot(2, 2, 4)
plt.plot(data3 ** 2)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.rc('font', family='NanumBarunGothic')
plt.rcParams["figure.figsize"] = (8, 6)

# %%
# data 생성
data_y = np.arange(1, 11)
data_x = np.arange(1, 11)

# 꺾은선 그래프 그리기
plt.subplot(2, 1, 1)
plt.plot(data_y)

# 막대 그래프 그래프
plt.subplot(2, 1, 2)
plt.bar(data_x, data_y)

# 그래프 출력
plt.show()
# Out:
# findfont: Font family ['NanumBarunGothic'] not found. Falling back to DejaVu Sans.

# %%
# data 생성
data_y = np.arange(11, 21)
data_x = np.arange(1, 11)

# 수평 막대 그래프 그래프
plt.barh(data_y, data_x)

# 그래프 출력
plt.show()

# %%
# ratio (모두 합쳐서 100이 되지 않으면 자동으로 전체의 합에서 각각의 비율을 나타냄)
data = [15, 30, 20, 35]

plt.pie(data, autopct='%.1f%%')

plt.show()

# %%
ratio = [15, 30, 20, 35]

# 각 영역의 범례
labels = ['A', 'B', 'C', 'D']

# 각 영역이 중심으로부터 떨어진 거리
explode = [0.05, 0.05, 0.05, 0.05]

# 각 영역의 색상
colors = ['lightpink', 'lightyellow', 'lightgreen', 'lightskyblue']

plt.pie(ratio, autopct='%.1f%%', labels=labels,
        explode=explode, colors=colors, shadow=True)

plt.show()

# %%
# 0~1 사이의 실수를 무작위으로 50개 생성 (x, y 좌표로 활용)
x = np.random.rand(50)
y = np.random.rand(50)

# 각 점들의 색상 부여를 위한 Array 생성 (데이터와 동일한 50개 필요)
colors = np.arange(50)

# 각 점들의 면적을 부여해서 다양한 점의 면적 표현
area = x * y * 2000

# 0~1 사이의 투명도를 설정하여 점이 겹쳤을 때를 더 예쁘게 표현 가능
alpha = 0.5

# 산점도 그래프 그리기 (여기서 cmap은 matplotlib에 정의된 컬러 조합임)
plt.scatter(x, y, s=area, c=colors, alpha=alpha, cmap='hsv')

# 산점도 그래프 우측에 컬러가 무엇을 뜻하는지 컬러바 표현
plt.colorbar()

# 그래프 출력
plt.show()

# %%
import pandas as pd

import numpy as np

import bar_chart_race as bcr

# %%
df = pd.read_csv('./premier.csv')
df.head()
# Out:
#     season               team  points   w   d   l   gf  ga  gd  pld  ...  d_h  \
# 0  2017-18    Manchester City     100  32   4   2  106  27  79   38  ...    2
# 1  2017-18  Manchester United      81  25   6   7   68  28  40   38  ...    2
# 2  2017-18  Tottenham Hotspur      77  23   8   7   74  36  38   38  ...    4
# 3  2017-18          Liverpool      75  21  12   5   84  38  46   38  ...    7
# 4  2017-18            Chelsea      70  21   7  10   62  38  24   38  ...    4
#
#    d_a  l_h  l_a  gf_h  gf_a  ga_h  ga_a  gd_h  gd_a
# 0    2    1    1    61    45    14    13    47    32
# 1    4    2    5    38    30     9    19    29    11
# 2    4    2    5    40    34    16    20    24    14
# 3    5    0    5    45    39    10    28    35    11
# 4    3    4    6    30    32    16    22    14    10
#
# [5 rows x 26 columns]

# %%
df = df[['season', 'team', 'points']]
df.head()
# Out:
#     season               team  points
# 0  2017-18    Manchester City     100
# 1  2017-18  Manchester United      81
# 2  2017-18  Tottenham Hotspur      77
# 3  2017-18          Liverpool      75
# 4  2017-18            Chelsea      70

# %%
df = df.pivot_table(values='points', index='season', columns='team')
df.head()
# Out:
# team     Arsenal  Aston Villa  Barnsley  Birmingham City  Blackburn Rovers  \
# season
# 1992-93     56.0         74.0       NaN              NaN              71.0
# 1993-94     71.0         57.0       NaN              NaN              84.0
# 1994-95     51.0         48.0       NaN              NaN              89.0
# 1995-96     63.0         63.0       NaN              NaN              61.0
# 1996-97     68.0         61.0       NaN              NaN              42.0
#
# team     Blackpool  Bolton Wanderers  Bournemouth  Bradford City  \
# season
# 1992-93        NaN               NaN          NaN            NaN
# 1993-94        NaN               NaN          NaN            NaN
# 1994-95        NaN               NaN          NaN            NaN
# 1995-96        NaN              29.0          NaN            NaN
# 1996-97        NaN               NaN          NaN            NaN
#
# team     Brighton and Hove Albion  ...  Sunderland  Swansea City  \
# season                             ...
# 1992-93                       NaN  ...         NaN           NaN
# 1993-94                       NaN  ...         NaN           NaN
# 1994-95                       NaN  ...         NaN           NaN
# 1995-96                       NaN  ...         NaN           NaN
# 1996-97                       NaN  ...        40.0           NaN
#
# team     Swindon Town  Tottenham Hotspur  Watford  West Bromwich Albion  \
# season
# 1992-93           NaN               59.0      NaN                   NaN
# 1993-94          30.0               45.0      NaN                   NaN
# 1994-95           NaN               62.0      NaN                   NaN
# 1995-96           NaN               61.0      NaN                   NaN
# 1996-97           NaN               46.0      NaN                   NaN
#
# team     West Ham United  Wigan Athletic  Wimbledon FC  \
# season
# 1992-93              NaN             NaN          54.0
# 1993-94             52.0             NaN          65.0
# 1994-95             50.0             NaN          56.0
# 1995-96             51.0             NaN          41.0
# 1996-97             42.0             NaN          56.0
#
# team     Wolverhampton Wanderers
# season
# 1992-93                      NaN
# 1993-94                      NaN
# 1994-95                      NaN
# 1995-96                      NaN
# 1996-97                      NaN
#
# [5 rows x 49 columns]

# %%
df = df.fillna(0)
df.head()
# Out:
# team     Arsenal  Aston Villa  Barnsley  Birmingham City  Blackburn Rovers  \
# season
# 1992-93     56.0         74.0       0.0              0.0              71.0
# 1993-94     71.0         57.0       0.0              0.0              84.0
# 1994-95     51.0         48.0       0.0              0.0              89.0
# 1995-96     63.0         63.0       0.0              0.0              61.0
# 1996-97     68.0         61.0       0.0              0.0              42.0
#
# team     Blackpool  Bolton Wanderers  Bournemouth  Bradford City  \
# season
# 1992-93        0.0               0.0          0.0            0.0
# 1993-94        0.0               0.0          0.0            0.0
# 1994-95        0.0               0.0          0.0            0.0
# 1995-96        0.0              29.0          0.0            0.0
# 1996-97        0.0               0.0          0.0            0.0
#
# team     Brighton and Hove Albion  ...  Sunderland  Swansea City  \
# season                             ...
# 1992-93                       0.0  ...         0.0           0.0
# 1993-94                       0.0  ...         0.0           0.0
# 1994-95                       0.0  ...         0.0           0.0
# 1995-96                       0.0  ...         0.0           0.0
# 1996-97                       0.0  ...        40.0           0.0
#
# team     Swindon Town  Tottenham Hotspur  Watford  West Bromwich Albion  \
# season
# 1992-93           0.0               59.0      0.0                   0.0
# 1993-94          30.0               45.0      0.0                   0.0
# 1994-95           0.0               62.0      0.0                   0.0
# 1995-96           0.0               61.0      0.0                   0.0
# 1996-97           0.0               46.0      0.0                   0.0
#
# team     West Ham United  Wigan Athletic  Wimbledon FC  \
# season
# 1992-93              0.0             0.0          54.0
# 1993-94             52.0             0.0          65.0
# 1994-95             50.0             0.0          56.0
# 1995-96             51.0             0.0          41.0
# 1996-97             42.0             0.0          56.0
#
# team     Wolverhampton Wanderers
# season
# 1992-93                      0.0
# 1993-94                      0.0
# 1994-95                      0.0
# 1995-96                      0.0
# 1996-97                      0.0
#
# [5 rows x 49 columns]

# %%
df.iloc[:] = df.iloc[:].cumsum()

# %%
df.head()
# Out:
# team     Arsenal  Aston Villa  Barnsley  Birmingham City  Blackburn Rovers  \
# season
# 1992-93     56.0         74.0       0.0              0.0              71.0
# 1993-94    127.0        131.0       0.0              0.0             155.0
# 1994-95    178.0        179.0       0.0              0.0             244.0
# 1995-96    241.0        242.0       0.0              0.0             305.0
# 1996-97    309.0        303.0       0.0              0.0             347.0
#
# team     Blackpool  Bolton Wanderers  Bournemouth  Bradford City  \
# season
# 1992-93        0.0               0.0          0.0            0.0
# 1993-94        0.0               0.0          0.0            0.0
# 1994-95        0.0               0.0          0.0            0.0
# 1995-96        0.0              29.0          0.0            0.0
# 1996-97        0.0              29.0          0.0            0.0
#
# team     Brighton and Hove Albion  ...  Sunderland  Swansea City  \
# season                             ...
# 1992-93                       0.0  ...         0.0           0.0
# 1993-94                       0.0  ...         0.0           0.0
# 1994-95                       0.0  ...         0.0           0.0
# 1995-96                       0.0  ...         0.0           0.0
# 1996-97                       0.0  ...        40.0           0.0
#
# team     Swindon Town  Tottenham Hotspur  Watford  West Bromwich Albion  \
# season
# 1992-93           0.0               59.0      0.0                   0.0
# 1993-94          30.0              104.0      0.0                   0.0
# 1994-95          30.0              166.0      0.0                   0.0
# 1995-96          30.0              227.0      0.0                   0.0
# 1996-97          30.0              273.0      0.0                   0.0
#
# team     West Ham United  Wigan Athletic  Wimbledon FC  \
# season
# 1992-93              0.0             0.0          54.0
# 1993-94             52.0             0.0         119.0
# 1994-95            102.0             0.0         175.0
# 1995-96            153.0             0.0         216.0
# 1996-97            195.0             0.0         272.0
#
# team     Wolverhampton Wanderers
# season
# 1992-93                      0.0
# 1993-94                      0.0
# 1994-95                      0.0
# 1995-96                      0.0
# 1996-97                      0.0
#
# [5 rows x 49 columns]
